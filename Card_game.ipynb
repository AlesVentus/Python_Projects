# %%
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card():
       
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return self.rank + " of " + self.suit

# %%
class Deck():
    
    def __init__(self):
        self.all_cards = []
        
        for suit in suits:
            for rank in ranks:
                created_card = Card(suit, rank)
                self.all_cards.append(created_card)       
                
    def shuffle_deck(self):
        random.shuffle(self.all_cards)
        
    def deal_card(self):
        return self.all_cards.pop()

# %%
class Player():
    
    def __init__(self, name):
        self.all_cards = []
        self.name = name
        
    def remove_one(self):
        return self.all_cards.pop(0)
    
    def add_cards(self, new_cards):
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)
            
    
    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards'

# %%
def hit_or_stand(deck,hand):
    global playing  # to control an upcoming while loop
    
    while True:
        x = input("Would you like to Hit or Stand? Enter 'h' or 's' ")
        
        if x[0].lower() == 'h':
            hit(deck,hand)  # hit() function defined above

        elif x[0].lower() == 's':
            print("Player stands. Dealer is playing.")
            playing = False

        else:
            print("Sorry, please try again.")
            continue
        break

# %%
player_1 = Player("One")
player_2 = Player("Two")

new_deck = Deck()
new_deck.shuffle_deck()

for x in range(26):
    player_1.add_cards(new_deck.deal_card())
    player_2.add_cards(new_deck.deal_card())

# %%
game_on = True

# %%
player_1 = Player("One")
player_2 = Player("Two")

new_deck = Deck()
new_deck.shuffle_deck()

for x in range(26):
    player_1.add_cards(new_deck.deal_card())
    player_2.add_cards(new_deck.deal_card())
    
    round_num = 0

    
game_on = True


while game_on:
    round_num += 1
    print(f'Current number of rounds is {round_num}')
    
    if len(player_1.all_cards) == 0:
        print('Player 1 Lost!!!')
        game_on= False
        break
        
        
    if len(player_2.all_cards) == 0:
        print('Player 2 Lost!!!')
        game_on= False
        break
        
    player_1_cards = []    
    player_1_cards.append(player_1.remove_one())
    
    player_2_cards = [] 
    player_2_cards.append(player_2.remove_one())
    
    at_war = True
    
    while at_war:
        
        if player_1_cards[-1].value > player_2_cards[-1].value:
            player_1.add_cards(player_1_cards)
            player_1.add_cards(player_2_cards)
            
            at_war = False
            
        elif player_2_cards[-1].value > player_1_cards[-1].value:
            player_2.add_cards(player_2_cards)
            player_2.add_cards(player_1_cards)
            
            at_war = False
            
        else:
            print('WAR !')
            if len(player_1.all_cards) < 3:
                print('player_1 is unable to war')
                print('player_2 wins !!!')
                game_on = False
                break
                
            if len(player_2.all_cards) < 3:
                print('player_2 is unable to war')
                print('player_1 wins !!!')
                game_on = False
                break
                
            else:
                for num in range(3):
                    player_1_cards.append(player_1.remove_one())
                    player_2_cards.append(player_2.remove_one())
# Out:
# Current number of rounds is 1
# Current number of rounds is 2
# Current number of rounds is 3
# Current number of rounds is 4
# Current number of rounds is 5
# Current number of rounds is 6
# Current number of rounds is 7
# Current number of rounds is 8
# Current number of rounds is 9
# Current number of rounds is 10
# Current number of rounds is 11
# Current number of rounds is 12
# Current number of rounds is 13
# Current number of rounds is 14
# Current number of rounds is 15
# Current number of rounds is 16
# Current number of rounds is 17
# Current number of rounds is 18
# Current number of rounds is 19
# WAR !
# Current number of rounds is 20
# Current number of rounds is 21
# Current number of rounds is 22
# Current number of rounds is 23
# Current number of rounds is 24
# Current number of rounds is 25
# Current number of rounds is 26
# Current number of rounds is 27
# Current number of rounds is 28
# Current number of rounds is 29
# Current number of rounds is 30
# Current number of rounds is 31
# Current number of rounds is 32
# Current number of rounds is 33
# Current number of rounds is 34
# Current number of rounds is 35
# WAR !
# Current number of rounds is 36
# Current number of rounds is 37
# Current number of rounds is 38
# Current number of rounds is 39
# Current number of rounds is 40
# Current number of rounds is 41
# Current number of rounds is 42
# Current number of rounds is 43
# Current number of rounds is 44
# WAR !
# Current number of rounds is 45
# Current number of rounds is 46
# Current number of rounds is 47
# Current number of rounds is 48
# Current number of rounds is 49
# Current number of rounds is 50
# Current number of rounds is 51
# Current number of rounds is 52
# Current number of rounds is 53
# Current number of rounds is 54
# Current number of rounds is 55
# Current number of rounds is 56
# Current number of rounds is 57
# Current number of rounds is 58
# Current number of rounds is 59
# Current number of rounds is 60
# Current number of rounds is 61
# Current number of rounds is 62
# Current number of rounds is 63
# Current number of rounds is 64
# Current number of rounds is 65
# Current number of rounds is 66
# Current number of rounds is 67
# Current number of rounds is 68
# Current number of rounds is 69
# Current number of rounds is 70
# Current number of rounds is 71
# Current number of rounds is 72
# Current number of rounds is 73
# Current number of rounds is 74
# Current number of rounds is 75
# Current number of rounds is 76
# Current number of rounds is 77
# Current number of rounds is 78
# Current number of rounds is 79
# Current number of rounds is 80
# Current number of rounds is 81
# Current number of rounds is 82
# Current number of rounds is 83
# Current number of rounds is 84
# Current number of rounds is 85
# Current number of rounds is 86
# WAR !
# Current number of rounds is 87
# Player 2 Lost!!!
